# %%
#laoding and importing 
import pandas as pd
df = pd.read_csv('housing.csv')

# %%
#quick data understanding
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
#checking null values
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df['total_bedrooms']= df['total_bedrooms'].fillna(
    df['total_bedrooms'].median()
)

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
#feature selection
X = df.drop("median_house_value",axis=1)
y = df['median_house_value']

# %%
#row and 
df.iloc[0]
# Out:
# longitude              -122.23
# latitude                 37.88
# housing_median_age        41.0
# total_rooms              880.0
# total_bedrooms           129.0
# population               322.0
# households               126.0
# median_income           8.3252
# median_house_value    452600.0
# ocean_proximity       NEAR BAY
# Name: 0, dtype: object

# %%
df.iloc[:,1]
# Out:
# 0        37.88
# 1        37.86
# 2        37.85
# 3        37.85
# 4        37.85
#          ...
# 20635    39.48
# 20636    39.49
# 20637    39.43
# 20638    39.43
# 20639    39.37
# Name: latitude, Length: 20640, dtype: float64

# %%
#droping unwantaed columns
df.drop('ocean_proximity',axis=1,inplace=True)

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0

# %%
#encoding categorical data 
df = pd.get_dummies(df)

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0

# %%
df[df['total_rooms']==7099]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1    -122.22     37.86                21.0       7099.0          1106.0
#
#    population  households  median_income  median_house_value
# 1      2401.0      1138.0         8.3014            358500.0

# %%
df.sort_values('median_house_value')
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13309    -122.74     39.71                16.0        255.0            73.0
# 12793    -123.17     40.31                36.0         98.0            28.0
# 15088    -117.02     36.40                19.0        619.0           239.0
# 5444     -117.86     34.24                52.0        803.0           267.0
# 1504     -118.33     34.15                39.0        493.0           168.0
# ...          ...       ...                 ...          ...             ...
# 12191    -122.43     37.79                52.0       3486.0           847.0
# 7150     -120.10     38.91                33.0       1561.0           282.0
# 2893     -122.43     37.79                52.0       6186.0          1566.0
# 12213    -122.01     37.27                27.0       3340.0           451.0
# 16347    -117.85     33.61                14.0       4340.0           741.0
#
#        population  households  median_income  median_house_value
# 13309        85.0        38.0         1.6607             14999.0
# 12793        18.0         8.0         0.5360             14999.0
# 15088       490.0       164.0         2.1000             14999.0
# 5444        628.0       225.0         4.1932             14999.0
# 1504        259.0       138.0         2.3667             17500.0
# ...           ...         ...            ...                 ...
# 12191      1248.0       813.0         7.2623            500001.0
# 7150         30.0        11.0         1.8750            500001.0
# 2893       2065.0      1374.0         5.8543            500001.0
# 12213      1220.0       447.0         8.8178            500001.0
# 16347      1505.0       670.0         7.5674            500001.0
#
# [20640 rows x 9 columns]

# %%
X = df.values

# %%
print(X)
# Out:
# [[-1.2223e+02  3.7880e+01  4.1000e+01 ...  1.2600e+02  8.3252e+00
#    4.5260e+05]
#  [-1.2222e+02  3.7860e+01  2.1000e+01 ...  1.1380e+03  8.3014e+00
#    3.5850e+05]
#  [-1.2224e+02  3.7850e+01  5.2000e+01 ...  1.7700e+02  7.2574e+00
#    3.5210e+05]
#  ...
#  [-1.2122e+02  3.9430e+01  1.7000e+01 ...  4.3300e+02  1.7000e+00
#    9.2300e+04]
#  [-1.2132e+02  3.9430e+01  1.8000e+01 ...  3.4900e+02  1.8672e+00
#    8.4700e+04]
#  [-1.2124e+02  3.9370e+01  1.6000e+01 ...  5.3000e+02  2.3886e+00
#    8.9400e+04]]
